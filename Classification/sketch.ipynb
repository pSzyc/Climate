# %% [markdown]
# # Sketch Engine

# %%
import pandas as pd
df = pd.read_csv("eco_wyborcza_colocates.csv")
df.columns
# Out:
# Index(['<doc text_id="', 'id', '" title="', 'title', '" source ="', 'source',
#        '" author ="', 'author', '" department="', 'department', '" date="',
#        'date', '">', 'text', '</doc>',
#        '<doc text_id="id" title="title" source ="source" author ="author" department="department" date="date">text</doc>'],
#       dtype='object')

# %%
df = df.drop(columns=df.columns[-1])

# %%
df.fillna("", inplace=True)

# %%
df[df.columns[-1]].to_csv("wyborcza_sketch.txt", index=False)

# %%
df = pd.read_csv("eco_wprost.csv")

# %%
columns = ['id', 'source', 'title','text', 'author', 'date', 'department']
for column in columns:
  if column not in df.columns:
    print(column)
    df[column] = None
# Out:
# department

# %%
df = df[columns]

# %%
pd.read_csv("eco_wyborcza.csv").date
# Out:
# 0       2015-01-02
# 1       2015-01-09
# 2       2015-01-12
# 3       2015-01-14
# 4       2015-01-14
#            ...
# 7223    2022-12-28
# 7224    2022-12-29
# 7225    2022-12-30
# 7226    2022-12-30
# 7227    2022-12-30
# Name: date, Length: 7228, dtype: object

# %%
for column in columns:
    df[f""]
